# %% [markdown]
# # PRE-PROCESSING

# %%
# IMPORTING PANDAS AND NUMPY
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#READING DATA IN CSV FORMAT
data=pd.read_csv("housing.csv")

# %%
#SHAPE OF THE DATA
data.shape
# Out:
# (20640, 10)

# %%
#FIRST 10 SAMPLES OF DATA
data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
# 5    -122.25     37.85                  52          919           213.0
# 6    -122.25     37.84                  52         2535           489.0
# 7    -122.25     37.84                  52         3104           687.0
# 8    -122.26     37.84                  42         2555           665.0
# 9    -122.25     37.84                  52         3549           707.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# ...

# %%
#LAST 5 SAMPLES OF DATA
data.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income ocean_proximity  \
# 20635         845         330         1.5603          INLAND
# 20636         356         114         2.5568          INLAND
# 20637        1007         433         1.7000          INLAND
# 20638         741         349         1.8672          INLAND
# 20639        1387         530         2.3886          INLAND
#
#        median_house_value
# 20635               78100
# 20636               77100
# 20637               92300
# 20638               84700
# ...

# %%
#COUNTING THE NUMBER OF VALUES OF LONGITUDE  
data["longitude"].value_counts()
# Out:
# -118.31    162
# -118.30    160
# -118.29    148
# -118.27    144
# -118.32    142
# -118.28    141
# -118.35    140
# -118.36    138
# -118.19    135
# -118.25    128
# -118.37    128
# -118.20    126
# -118.14    125
# -118.26    121
# -118.13    121
# -118.18    120
# -118.34    119
# -118.21    118
# -118.15    116
# -118.12    112
# -118.10    109
# -118.38    107
# -118.17    106
# -118.43    106
# -118.16    103
# -122.27    103
# -118.33    102
# -118.22    100
# -117.90    100
# -118.11    100
#           ...
# -123.28      1
# -115.75      1
# -115.94      1
# -116.12      1
# -116.30      1
# -115.39      1
# -116.16      1
# -114.68      1
# -123.66      1
# -123.43      1
# -115.32      1
# -124.27      1
# -114.63      1
# -115.80      1
# -123.98      1
# -114.64      1
# -124.35      1
# -114.56      1
# -116.55      1
# -116.08      1
# -123.04      1
# -123.92      1
# -124.22      1
# -123.12      1
# -123.63      1
# -115.72      1
# -123.68      1
# ...

# %%
   #CHECKING THE NULL VALUES OF ALL FEATURES IN THE DATA
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
#FILLING THE NULL VALUES WITH MEAN 
data["total_bedrooms"]=data["total_bedrooms"].fillna(np.mean(data["total_bedrooms"]))

# %%
  #ADDING THE NULL VALUES OF EACH FEATURE
data.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %%
#DATA TYPES OF EACH VARIABLE
np
data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# ocean_proximity        object
# median_house_value      int64
# dtype: object

# %%
#PLOTING VALUES BETWEEN MRP AND OUTPUT VARIABLE 
plt.scatter(data.housing_median_age,data.median_house_value)
plt.title("Relationship between Item MRP and Target Variable")
plt.show()

# %%
#HISTOGRAMS FOR EACH INDEPENDENT VARIABLE AGAINST THE OUTPUT
data.hist(figsize=(20,20),color='grey')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # LABEL ENCODING

# %%
#LABEL ENCODING
lb=LabelEncoder()
print(data["ocean_proximity"].unique())
data.head()
# Out:
# ['NEAR BAY' '<1H OCEAN' 'INLAND' 'NEAR OCEAN' 'ISLAND']
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
#DEPENDENT AND INDEPENDENT VARIABLES
x=data.iloc[:,:-1].values
y=data.iloc[:,9].values
y
# Out:
# array([452600, 358500, 352100, ...,  92300,  84700,  89400], dtype=int64)

# %%
#FIT AND TRANSFORM THE CATEGORICAL FEATURE
x[:,8]=lb.fit_transform(x[:,8])

# %%
x
# Out:
# array([[-122.23, 37.88, 41, ..., 126, 8.3252, 3],
#        [-122.22, 37.86, 21, ..., 1138, 8.3014, 3],
#        [-122.24, 37.85, 52, ..., 177, 7.2574, 3],
#        ...,
#        [-121.22, 39.43, 17, ..., 433, 1.7, 1],
#        [-121.32, 39.43, 18, ..., 349, 1.8672, 1],
#        [-121.24, 39.37, 16, ..., 530, 2.3886, 1]], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # ONE HOT ENCODING

# %%
#ONE HOT ENCODING
ohe=OneHotEncoder(categorical_features=[8])

# %%
x=ohe.fit_transform(x).toarray()

# %%
print(x[:20,:6])
# Out:
# [[   0.      0.      0.      1.      0.   -122.23]
#  [   0.      0.      0.      1.      0.   -122.22]
#  [   0.      0.      0.      1.      0.   -122.24]
#  [   0.      0.      0.      1.      0.   -122.25]
#  [   0.      0.      0.      1.      0.   -122.25]
#  [   0.      0.      0.      1.      0.   -122.25]
#  [   0.      0.      0.      1.      0.   -122.25]
#  [   0.      0.      0.      1.      0.   -122.25]
#  [   0.      0.      0.      1.      0.   -122.26]
#  [   0.      0.      0.      1.      0.   -122.25]
#  [   0.      0.      0.      1.      0.   -122.26]
#  [   0.      0.      0.      1.      0.   -122.26]
#  [   0.      0.      0.      1.      0.   -122.26]
#  [   0.      0.      0.      1.      0.   -122.26]
#  [   0.      0.      0.      1.      0.   -122.26]
#  [   0.      0.      0.      1.      0.   -122.26]
#  [   0.      0.      0.      1.      0.   -122.27]
#  [   0.      0.      0.      1.      0.   -122.27]
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
#SPLITTING TRAIN AND TEST DATA
x_train, x_test, y_train, y_test = train_test_split (x, y, test_size = 0.2, 
                                                     random_state = 0)

# %%
#PRINTING TRAINING AND TESTING DATA
x_train,x_test,y_train,y_test
# Out:
# (array([[0.0000e+00, 1.0000e+00, 0.0000e+00, ..., 2.2800e+02, 6.5000e+01,
#          4.2386e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.4850e+03, 4.4700e+02,
#          4.3898e+00],
#         [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.0220e+03, 3.6800e+02,
#          3.9333e+00],
#         ...,
#         [0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 7.0400e+02, 3.9300e+02,
#          3.1977e+00],
#         [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.0520e+03, 4.6800e+02,
#          5.6315e+00],
#         [0.0000e+00, 1.0000e+00, 0.0000e+00, ..., 1.0240e+03, 2.9800e+02,
#          1.3882e+00]]),
#  array([[0.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.5510e+03, 3.7100e+02,
#          4.1518e+00],
#         [1.0000e+00, 0.0000e+00, 0.0000e+00, ..., 1.2960e+03, 4.2900e+02,
#          5.7796e+00],
#         [0.0000e+00, 1.0000e+00, 0.0000e+00, ..., 1.5540e+03, 5.3400e+02,
#          4.3487e+00],
#         ...,
# ...

# %% [markdown]
# # STANDARDISATION

# %%
#STANDARDISATION
from sklearn.preprocessing import StandardScaler
independent_scalar = StandardScaler()
x_train = independent_scalar.fit_transform (x_train) #fit and transform
x_test = independent_scalar.transform (x_test) # only transform
print(x_train)
# Out:
# [[-0.89150581  1.46934754 -0.01348032 ... -1.04760128 -1.1356496
#    0.19001247]
#  [-0.89150581 -0.68057418 -0.01348032 ...  0.05210918 -0.13688171
#    0.26931072]
#  [ 1.12169768 -0.68057418 -0.01348032 ... -0.35295521 -0.34343319
#    0.02989505]
#  ...
#  [-0.89150581 -0.68057418 -0.01348032 ... -0.63116359 -0.27806879
#   -0.35589721]
#  [ 1.12169768 -0.68057418 -0.01348032 ... -0.32670914 -0.08197562
#    0.92053182]
#  [-0.89150581  1.46934754 -0.01348032 ... -0.35120548 -0.52645348
#   -1.30490629]]

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # LINEAR REGRESSION

# %%
#LINEAR REGRESSION
lr=LinearRegression()

# %%
#PREDICTING VALUES
lr.fit(x_train, y_train)
predictions = lr.predict(x_test)

# %%
print(predictions)
% pylab inline
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score, mean_squared_error
print(sqrt(mean_squared_error(y_test, predictions)))
# Out:
# [217472.46204933 287540.46204933 178808.46204933 ...  88482.46204933
#  254655.46204933 213382.46204933]
# Populating the interactive namespace from numpy and matplotlib
# 68687.74865795692

# %%
#CALCULATING THE ACCURACY OF LINEAR REGRESSION
accuracy=lr.score(x_test,y_test)
accuracy*100
# Out:
# 63.8177148049885

# %% [markdown]
# # DECISION TREE

# %%
#APPLYING DECISION TREE
dtree_reg = DecisionTreeRegressor(max_depth=23,min_samples_leaf = 7, max_features = 'sqrt',random_state=42,min_samples_split=5)

# %%
dtree_reg.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=23, max_features='sqrt',
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=7,
#            min_samples_split=5, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=42, splitter='best')

# %%
#DISPLAYING RMS AND ACCURACY 
from sklearn.metrics import accuracy_score
pred = dtree_reg.predict(x_test)
print("error:")
print(sqrt(mean_squared_error(y_test, pred)))
acc=dtree_reg.score(x_test,y_test)
print("accuracy:")
print(acc*100)
# Out:
# error:
# 61090.44468221142
# accuracy:
# 71.3790528733377

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # RANDOM FOREST

# %% [markdown]
# model = RandomForestRegressor(max_depth = 25, max_features = 'sqrt',n_estimators = 650,random_state=2)
# model.fit(x_train,y_train)
# predicted_train = model.predict(x_test)
# true_value = y_test
# print("error:")
# print(sqrt(mean_squared_error(y_test, predicted_train)))
# acc=model.score(x_test,y_test)
# print("accuracy:")
# print(acc*100)

# %% [markdown]
# # LINEAR REGRESSION WITH ONE INDEPENDENT VARIABLE

# %%
from sklearn.cross_validation import train_test_split
xs= data.iloc[:, 7].values
ys =data.iloc[:, 9].values
#Spliting the dataset into Training set and Test Set
xtrain, xtest, ytrain, ytest = train_test_split(xs, ys, test_size= 0.05, random_state=3)
#linnear Regression
xtrain= xtrain.reshape(-1, 1)
ytrain= ytrain.reshape(-1, 1)
xtest = xtest.reshape(-1, 1)
regressor = LinearRegression()
regressor.fit(xtrain,ytrain)
ypred = regressor.predict(xtest)
from sklearn.metrics import mean_squared_error
from math import sqrt
rms = sqrt(mean_squared_error(ytest,ypred))
print("root mean square error: "+str(rms))
accuracy = regressor.score(xtest,ytest)
accu=(accuracy*100,'%')
print("accuracy :"+str(accu))
plt.scatter(xtrain, ytrain)
plt.plot(xtest, ypred, color='red')
plt.show()
# Out:
# C:\Users\nisch\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# root mean square error: 80527.45996876547
# accuracy :(51.237932070183255, '%')

# %%
fig = plt.figure(figsize=(25,8))
plt.scatter(ytest,ypred,marker="*",s=100)
plt.scatter(ytrain,regressor.predict(xtrain),marker="s",s=15,alpha=0.9)
plt.xlabel(" Actual median_house_value")
plt.ylabel(" Predicted median_house_value")
# Out:
# Text(0,0.5,' Predicted median_house_value')
